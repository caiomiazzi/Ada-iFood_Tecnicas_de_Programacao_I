# %% [markdown]
# # Melhores Músicas do Spotify de 1998-2020

# %% [markdown]
# ## 1. Sobre
#
# Esse dataset engloba estatísticas de músicas referentes às 2.000 faixas mais populares no Spotify durante o período de 2000 a 2019. Com cerca de 18 colunas, cada uma detalhando informações sobre a respectiva faixa e suas características.
#
# Usamos o dataset obtido do Kaggle: https://www.kaggle.com/datasets/paradisejoy/top-hits-spotify-from-20002019

# %% [markdown]
# ## 1.1 Dicionário de Colunas
#
# artist: Nome do artista.
#
# song: Nome da faixa.
#
# duration_ms: Duração da faixa em milissegundos.
#
# explicit: As letras ou conteúdo de uma música ou vídeo musical contêm um ou mais critérios que podem ser considerados ofensivos ou inadequados para crianças.
#
# year: Ano de lançamento da faixa.
#
# popularity: Quanto maior o valor, mais popular é a música.
#
# danceability: A dançabilidade descreve o quão adequada uma faixa é para dançar com base em uma combinação de elementos musicais, incluindo tempo, estabilidade rítmica, força do ritmo e regularidade geral. Um valor de 0,0 é o menos dançável e 1,0 é o mais dançável.
#
# energy: A energia é uma medida de 0,0 a 1,0 e representa uma medida perceptual de intensidade e atividade.
#
# key: A tonalidade da faixa. Números inteiros mapeiam para tons usando a notação padrão de Classe de Altura. Por exemplo, 0 = Dó, 1 = Dó sustenido/Ré bemol, 2 = Ré, e assim por diante. Se nenhuma tonalidade for detectada, o valor é -1.
#
# loundness: O volume geral de uma faixa em decibéis (dB). Os valores de volume são calculados em média em toda a faixa e são úteis para comparar o volume relativo das faixas. O volume é a qualidade de um som que é o principal correlato psicológico da força física (amplitude). Os valores geralmente variam entre -60 e 0 dB.
#
# mode: O modo indica a modalidade (maior ou menor) de uma faixa, o tipo de escala de onde seu conteúdo melódico é derivado. Maior é representado por 1 e menor por 0.
#
# speechiness: A articulação detecta a presença de palavras faladas em uma faixa. Quanto mais exclusivamente parecida com fala a gravação (por exemplo, talk show, audiolivro, poesia), mais próximo de 1,0 é o valor do atributo. Valores acima de 0,66 descrevem faixas que provavelmente são feitas inteiramente de palavras faladas. Valores entre 0,33 e 0,66 descrevem faixas que podem conter tanto música quanto fala, seja em seções ou sobrepostas, incluindo casos como rap. Valores abaixo de 0,33 provavelmente representam faixas musicais e outras não semelhantes a fala.
#
# acousticness: Uma medida de confiança de 0,0 a 1,0 de se a faixa é acústica. 1,0 representa alta confiança de que a faixa é acústica.
#
# instrumentalness: Prevê se uma faixa não contém vocais. Sons como "ooh" e "aah" são tratados como instrumentais nesse contexto. Faixas de rap ou de palavras faladas são claramente "vocais". Quanto mais próximo o valor de instrumentalidade estiver de 1,0, maior a probabilidade de a faixa não conter conteúdo vocal. Valores acima de 0,5 são destinados a representar faixas instrumentais, mas a confiança é maior à medida que o valor se aproxima de 1,0.
#
# liveness: Detecta a presença de uma plateia na gravação. Valores de vivacidade mais altos representam uma probabilidade aumentada de que a faixa foi executada ao vivo. Um valor acima de 0,8 fornece uma forte probabilidade de que a faixa seja ao vivo.
#
# valence: Uma medida de 0,0 a 1,0 que descreve a positividade musical transmitida por uma faixa. Faixas com alta valência soam mais positivas (por exemplo, felizes, alegres, eufóricas), enquanto faixas com baixa valência soam mais negativas (por exemplo, tristes, deprimidas, irritadas).
#
# tempo: O andamento estimado geral de uma faixa em batidas por minuto (BPM). Em terminologia musical, andamento é a velocidade ou ritmo de uma peça dada e deriva diretamente da duração média do batimento.
#
# genre: Gênero da faixa.

# %% [markdown]
# ## 2. Código da Análise

# %%
# Importando as Bibliotecas Necessárias
import numpy as np
import pandas as pd

# %% [markdown]
# ### Visão Geral dos dados

# %%
# Lendo o arquivo
df = pd.read_csv("songs_normalize.csv")

# %%
# Formato do dataset
df.shape
# Out:
# (2000, 18)

# %%
# Visualizando a nossa base
display(df)

# %%
# Verificando os valores nulos e tipos de dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            2000 non-null   object
#  1   song              2000 non-null   object
#  2   duration_ms       2000 non-null   int64
#  3   explicit          2000 non-null   bool
#  4   year              2000 non-null   int64
#  5   popularity        2000 non-null   int64
#  6   danceability      2000 non-null   float64
#  7   energy            2000 non-null   float64
#  8   key               2000 non-null   int64
#  9   loudness          2000 non-null   float64
#  10  mode              2000 non-null   int64
#  11  speechiness       2000 non-null   float64
#  12  acousticness      2000 non-null   float64
#  13  instrumentalness  2000 non-null   float64
#  14  liveness          2000 non-null   float64
#  15  valence           2000 non-null   float64
#  16  tempo             2000 non-null   float64
#  17  genre             2000 non-null   object
# dtypes: bool(1), float64(9), int64(5), object(3)
# memory usage: 267.7+ KB

# %%
# Analisando algumas informações estatísticas
df.describe()
# Out:
#        duration_min         year   popularity  danceability       energy  \
# count   1941.000000  1941.000000  1941.000000   1941.000000  1941.000000
# mean       3.809916  2009.520350    59.633179      0.667814     0.721549
# std        0.654163     5.875532    21.501053      0.140608     0.152872
# min        1.883333  1998.000000     0.000000      0.129000     0.054900
# 25%        3.391767  2004.000000    56.000000      0.581000     0.624000
# 50%        3.719767  2010.000000    65.000000      0.676000     0.739000
# 75%        4.132433  2015.000000    73.000000      0.765000     0.840000
# max        8.069100  2020.000000    89.000000      0.975000     0.999000
#
#                key     loudness         mode  speechiness  acousticness  \
# count  1941.000000  1941.000000  1941.000000  1941.000000   1941.000000
# mean      5.369397    -5.514082     0.553323     0.103783      0.128173
# std       3.615270     1.938950     0.497277     0.096148      0.172584
# min       0.000000   -20.514000     0.000000     0.023200      0.000019
# 25%       2.000000    -6.490000     0.000000     0.039700      0.013500
# 50%       6.000000    -5.285000     1.000000     0.061000      0.055800
# 75%       8.000000    -4.168000     1.000000     0.129000      0.176000
# max      11.000000    -0.276000     1.000000     0.576000      0.976000
#
#        instrumentalness     liveness      valence        tempo
# count       1941.000000  1941.000000  1941.000000  1941.000000
# mean           0.015372     0.181726     0.552966   120.158442
# std            0.088371     0.140910     0.220845    26.990475
# min            0.000000     0.021500     0.038100    60.019000
# 25%            0.000000     0.088400     0.390000    98.986000
# 50%            0.000000     0.124000     0.560000   120.028000
# 75%            0.000069     0.242000     0.731000   134.199000
# max            0.985000     0.853000     0.973000   210.851000

# %%
# Checando os valores nulos
df.isnull().sum()
# Out:
# artist              0
# song                0
# duration_min        0
# explicit            0
# year                0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# genre               0
# dtype: int64

# %% [markdown]
# ### Tratando e limpando os dados

# %%
# Checando os valores duplicados
df.duplicated().value_counts()
# Out:
# False    1941
# True       59
# Name: count, dtype: int64

# %%
# Renomear coluna "duration_ms" para "duration_min" e converter os valores em milisegundos para minutos
df.rename(columns={'duration_ms': 'duration_min'}, inplace=True)

df['duration_min'] = df['duration_min'] / 60000 # 1 minuto é igual a 60000 milisegundos

display(df)

# %%
# Vizualizando alguns valores duplicados
df[df.duplicated()].head()
# Out:
#               artist                      song  duration_min  explicit  year  \
# 161      Craig David                Fill Me In      4.286667     False  2000
# 179  Destiny's Child  Independent Women, Pt. 1      3.685550     False  2001
# 187        Gabrielle                      Rise      3.651550     False  2001
# 215      Linkin Park                In the End      3.614667     False  2000
# 236    Kylie Minogue           Spinning Around      3.464433     False  2000
#
#      popularity  danceability  energy  key  loudness  mode  speechiness  \
# 161          60         0.682   0.744    8    -6.981     1       0.0365
# 179          65         0.730   0.602    6    -3.782     0       0.2060
# 187          60         0.558   0.481    8    -9.487     1       0.0260
# 215          83         0.556   0.864    3    -5.870     0       0.0584
# 236          55         0.761   0.662    6    -7.645     0       0.0548
#
#      acousticness  instrumentalness  liveness  valence    tempo  \
# 161       0.37600          0.009510    0.0600    0.827  132.493
# 179       0.36200          0.000004    0.1690    0.927   97.954
# 187       0.31500          0.000009    0.0900    0.631  144.673
# 215       0.00958          0.000000    0.2090    0.400  105.143
# 236       0.29200          0.000062    0.0956    0.631  120.043
#
#                      genre
# 161      hip hop, pop, R&B
# 179               pop, R&B
# 187               pop, R&B
# 215            rock, metal
# 236  pop, Dance/Electronic

# %%
# Removendo as duplicatas
df.drop_duplicates(inplace=True)

# %%
# Eliminado os registros iguais com a coluna "popularity" diferente
df.drop_duplicates(subset=['artist', 'song', 'year'], keep='last', inplace=True)

# %%
df.pivot_table(index=['artist', 'song', 'duration_min', 'explicit', 'year',
       'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'genre'], values= 'popularity', aggfunc='max').reset_index()
# Out:
#          artist                     song  duration_min  explicit  year  \
# 0        *NSYNC              Bye Bye Bye      3.342667     False  2000
# 1        *NSYNC               Girlfriend      4.226667     False  2001
# 2        *NSYNC                     Gone      4.866667     False  2001
# 3        *NSYNC         It's Gonna Be Me      3.184000     False  2000
# 4           112            It's Over Now      4.415550     False  2001
# ...         ...                      ...           ...       ...   ...
# 1932   t.A.T.u.  All The Things She Said      3.574000      True  2020
# 1933  will.i.am               #thatPOWER      4.658433     False  2013
# 1934  will.i.am             Heartbreaker      5.464667      True  2007
# 1935  will.i.am           Scream & Shout      4.723333      True  2013
# 1936  will.i.am             This Is Love      4.650433     False  2013
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.614   0.928    8    -4.806     0       0.0516       0.04080
# 1            0.745   0.807    0    -5.191     0       0.0884       0.08870
# 2            0.699   0.403   11    -8.564     0       0.0614       0.42100
# 3            0.644   0.874    0    -4.666     0       0.0801       0.04590
# 4            0.660   0.710    1    -4.541     1       0.0409       0.01060
# ...            ...     ...  ...       ...   ...          ...           ...
# 1932         0.527   0.834    5    -5.767     0       0.0474       0.04110
# 1933         0.797   0.608    6    -6.096     0       0.0584       0.00112
# 1934         0.788   0.549    9    -8.793     0       0.0732       0.03520
# 1935         0.772   0.685    5    -6.849     1       0.0696       0.01900
# 1936         0.535   0.796    0    -3.446     0       0.0445       0.00473
#
#       instrumentalness  liveness  valence    tempo              genre  \
# 0             0.001040    0.0845    0.879  172.656                pop
# 1             0.000015    0.0283    0.858   93.967                pop
# 2             0.000000    0.1260    0.500  113.922                pop
# 3             0.000002    0.0584    0.882  165.090                pop
# 4             0.000007    0.0736    0.233   97.988  hip hop, pop, R&B
# ...                ...       ...      ...      ...                ...
# 1932          0.005990    0.1050    0.381  179.920                pop
# 1933          0.000077    0.0748    0.402  127.999       hip hop, pop
# 1934          0.127000    0.1470    0.449  120.051       hip hop, pop
# 1935          0.000090    0.1310    0.501  130.033       hip hop, pop
# 1936          0.000000    0.1450    0.282  128.954       hip hop, pop
#
#       popularity
# 0             65
# 1             50
# 2             45
# 3             60
# 4             57
# ...          ...
# 1932          39
# 1933          68
# 1934          46
# 1935          78
# 1936          62
#
# [1937 rows x 18 columns]

# %%
# Conferindo a Exclusão
df[df['song'] == "Like Toy Soldiers"]
# Out:
#      artist               song  duration_ms  explicit  year  popularity  \
# 589  Eminem  Like Toy Soldiers       296880      True  2004          67
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 589          0.52   0.768    8    -3.489     0        0.359        0.0193
#
#      instrumentalness  liveness  valence   tempo    genre
# 589           0.00034     0.104    0.398  79.178  hip hop

# %%
# Formato depois da remoção de linhas
df.shape
# Out:
# (1941, 18)

# %%
# Selecionando uma das linhas para conferirmos a duplicidade
df[df['song'] == 'In the End']
# Out:
#           artist        song  duration_min  explicit  year  popularity  \
# 20   Linkin Park  In the End      3.614667     False  2000          83
# 215  Linkin Park  In the End      3.614667     False  2000          83
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 20          0.556   0.864    3     -5.87     0       0.0584       0.00958
# 215         0.556   0.864    3     -5.87     0       0.0584       0.00958
#
#      instrumentalness  liveness  valence    tempo        genre
# 20                0.0     0.209      0.4  105.143  rock, metal
# 215               0.0     0.209      0.4  105.143  rock, metal

# %%
# Por que temos músicas repetidas nessa consulta? Vamos analisar isso melhor.
df[df['song'] == "Like Toy Soldiers"]
# Out:
#      artist               song  duration_ms  explicit  year  popularity  \
# 495  Eminem  Like Toy Soldiers       296880      True  2004          48
# 589  Eminem  Like Toy Soldiers       296880      True  2004          67
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 495          0.52   0.768    8    -3.489     0        0.359        0.0193
# 589          0.52   0.768    8    -3.489     0        0.359        0.0193
#
#      instrumentalness  liveness  valence   tempo    genre
# 495           0.00034     0.104    0.398  79.178  hip hop
# 589           0.00034     0.104    0.398  79.178  hip hop

# %% [markdown]
# # Analise Exploratória de Dados

# %% [markdown]
# ### Verificando a relação da média de duração da musica pelo ano de seu lançamento.

# %%
import matplotlib.pyplot as plt

# Agrupar por ano e calcular a média da duração
avg_duration_by_year = df.groupby('year')['duration_min'].mean()

# Plotar o gráfico de linha
plt.figure(figsize=(12, 6))
avg_duration_by_year.plot(kind='line', marker='o', linestyle='-', color='b')
plt.title('Média de Duração por Ano')
plt.xlabel('Ano')
plt.ylabel('Média de Duração (min)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Analise com foco no ano

# %% [markdown]
# - Verificando a musica com o ano de lançamento mais antigo e mais recente

# %%
# Descobrindo o período da análise inicial
ano_inicial = df['year'].min()
print(f'Ano inicial da análise: {ano_inicial}')

# Descobrindo o período da análise final
ano_final = df['year'].max()
print(f'Ano final da análise: {ano_final}')
# Out:
# Ano inicial da análise: 1998
# Ano final da análise: 2020

# %%
# Ano a ano das melhores músicas
df['year'].value_counts(ascending=True)
# Out:
# year
# 1998      1
# 2020      3
# 1999     38
# 2000     71
# 2009     82
# 2002     86
# 2013     87
# 2019     89
# 2007     90
# 2003     91
# 2008     91
# 2006     93
# 2015     93
# 2004     95
# 2011     96
# 2016     98
# 2014    100
# 2005    101
# 2010    103
# 2018    104
# 2001    106
# 2017    110
# 2012    113
# Name: count, dtype: int64

# %% [markdown]
# ### Analise com foto no genero

# %%
# Gêneros Musicais que mais apareceram no dataset
df['genre'].value_counts().head(20)
# Out:
# genre
# pop                               416
# hip hop, pop                      267
# hip hop, pop, R&B                 236
# pop, Dance/Electronic             216
# pop, R&B                          172
# hip hop                           121
# hip hop, pop, Dance/Electronic     75
# rock                               57
# Dance/Electronic                   41
# rock, pop                          39
# rock, metal                        36
# pop, latin                         28
# pop, rock                          26
# set()                              22
# latin                              15
# hip hop, Dance/Electronic          15
# pop, rock, metal                   14
# hip hop, pop, latin                14
# R&B                                13
# pop, rock, Dance/Electronic        12
# Name: count, dtype: int64

# %%
# Gêneros musicais por popularidade
df.groupby('genre').sum().sort_values(by='popularity', ascending=False)['popularity']
# Out:
# genre
# pop                                      25403
# hip hop, pop                             17761
# hip hop, pop, R&B                        14408
# pop, Dance/Electronic                    11794
# pop, R&B                                 10284
# hip hop                                   7979
# hip hop, pop, Dance/Electronic            4660
# rock                                      3885
# rock, pop                                 2860
# rock, metal                               2695
# Dance/Electronic                          2122
# pop, latin                                1613
# pop, rock                                 1500
# set()                                     1264
# hip hop, Dance/Electronic                  970
# latin                                      936
# hip hop, pop, latin                        893
# pop, rock, metal                           826
# R&B                                        786
# metal                                      648
# pop, rock, Dance/Electronic                629
# hip hop, pop, rock                         550
# country                                    530
# pop, country                               527
# pop, Folk/Acoustic                         424
# rock, pop, Dance/Electronic                411
# pop, R&B, Dance/Electronic                 404
# rock, pop, metal                           242
# hip hop, pop, R&B, Dance/Electronic        193
# hip hop, R&B                               191
# pop, rock, Folk/Acoustic                   158
# Folk/Acoustic, pop                         156
# hip hop, pop, R&B, latin                   150
# hip hop, rock, pop                         150
# World/Traditional, pop, Folk/Acoustic      135
# rock, blues, latin                         123
# World/Traditional, rock                    120
# World/Traditional, hip hop                 118
# pop, easy listening, jazz                  115
# rock, pop, metal, Dance/Electronic          76
# hip hop, latin, Dance/Electronic            72
# easy listening                              72
# rock, Folk/Acoustic, pop                    71
# World/Traditional, Folk/Acoustic            69
# hip hop, country                            69
# Folk/Acoustic, rock, pop                    68
# rock, Folk/Acoustic, easy listening         65
# rock, classical                             63
# hip hop, pop, country                       62
# World/Traditional, pop                      61
# rock, easy listening                        60
# pop, R&B, easy listening                    60
# rock, blues                                 59
# rock, R&B, Folk/Acoustic, pop               58
# pop, easy listening, Dance/Electronic       58
# rock, Dance/Electronic                      54
# World/Traditional, rock, pop                35
# Folk/Acoustic, rock                          0
# country, latin                               0
# Name: popularity, dtype: int64

# %%
# Verificando a quantidade de vezes que um subgenero aparece no df


df_genres = df['genre'].value_counts().reset_index()
df_genres.columns = ['genre', 'count']

df_subgenres = pd.DataFrame(columns=['subgenre', 'count'])


for index, row in df_genres.iterrows():
    genre = row['genre']
    count = row['count']

    subgenres = [subgenre.strip() for subgenre in genre.split(',')]

    df_subgenres = pd.concat([df_subgenres, pd.DataFrame({'subgenre': subgenres, 'count': count})])

df_subgenres_total = df_subgenres.groupby('subgenre')['count'].sum().reset_index()


df_subgenres_total = df_subgenres_total.sort_values(by='count', ascending=False)


print(df_subgenres_total)
# Out:
#              subgenre count
# 12                pop  1633
# 8             hip hop   778
# 2                 R&B   452
# 0    Dance/Electronic   390
# 13               rock   234
# 11              metal    66
# 10              latin    64
# 14              set()    22
# 6             country    21
# 1       Folk/Acoustic    20
# 3   World/Traditional    10
# 7      easy listening     7
# 4               blues     4
# 9                jazz     2
# 5           classical     1

# %%
#Verificando a quantidade de vezes que o termo de um genero aparece na lista de generos

df_genres = pd.DataFrame({'genre': df['genre'].unique()})


def contaSubgenero(genre_string):

    subgeneros = [subgenre.strip() for subgenre in genre_string.split(',')]
    return subgeneros


df_genres['subgenres'] = df_genres['genre'].apply(contaSubgenero)


df_subgenres = pd.DataFrame(columns=['subgenre', 'count'])


for _, row in df_genres.iterrows():
    subgenres = row['subgenres']


    df_subgenres = pd.concat([df_subgenres, pd.DataFrame({'subgenre': subgenres})])


subgenre_counts = df_subgenres['subgenre'].value_counts().reset_index()
subgenre_counts.columns = ['subgenre', 'count']


print(subgenre_counts)
# Out:
#              subgenre  count
# 0                 pop     34
# 1                rock     24
# 2             hip hop     15
# 3    Dance/Electronic     12
# 4       Folk/Acoustic     10
# 5                 R&B      9
# 6               latin      7
# 7      easy listening      6
# 8   World/Traditional      6
# 9             country      5
# 10              metal      5
# 11              blues      2
# 12              set()      1
# 13               jazz      1
# 14          classical      1

# %%
# Top 10 músicas que mais aparecem no dataset
df[['song','artist', 'genre']].value_counts().head(16)
# Out:
# song                      artist              genre
# I Knew You Were Trouble.  Taylor Swift        pop                      2
# If You're Not The One     Daniel Bedingfield  pop                      2
# Talking Body              Tove Lo             pop, Dance/Electronic    2
# Laffy Taffy               D4L                 hip hop, pop             2
# Stickwitu                 The Pussycat Dolls  pop, R&B                 2
# Stereo Love - Radio Edit  Edward Maya         pop                      2
# Latch                     Disclosure          pop, Dance/Electronic    2
# Team                      Lorde               pop, Dance/Electronic    2
# White Flag                Dido                pop                      2
# Leave Right Now           Will Young          pop                      2
# Bodak Yellow              Cardi B             hip hop, pop             2
# Crank That (Soulja Boy)   Soulja Boy          hip hop, pop             2
# Down                      Jay Sean            hip hop, pop, R&B        2
# Stole the Show            Kygo                pop, Dance/Electronic    2
# If I Die Young            The Band Perry      country                  2
# Try                       P!nk                pop                      2
# Name: count, dtype: int64

# %%
# Gêneros musicais por popularidade
df.pivot_table(index='genre', values='popularity', aggfunc='sum').sort_values(by='popularity', ascending=False).head(20)
# Out:
#                                 popularity
# genre
# pop                                  25403
# hip hop, pop                         17761
# hip hop, pop, R&B                    14408
# pop, Dance/Electronic                11794
# pop, R&B                             10284
# hip hop                               7979
# hip hop, pop, Dance/Electronic        4660
# rock                                  3885
# rock, pop                             2860
# rock, metal                           2695
# Dance/Electronic                      2122
# pop, latin                            1613
# pop, rock                             1500
# set()                                 1264
# hip hop, Dance/Electronic              970
# latin                                  936
# hip hop, pop, latin                    893
# pop, rock, metal                       826
# R&B                                    786
# metal                                  648

# %% [markdown]
# ### Analise com foco no artista

# %%
# Top 10 Artistas que mais apareceram no Dataset
df[['artist','genre']].value_counts().head(10)
# Out:
# artist          genre
# Rihanna         hip hop, pop, R&B                 23
# Drake           hip hop, pop, R&B                 23
# Eminem          hip hop                           21
# Calvin Harris   hip hop, pop, Dance/Electronic    20
# Britney Spears  pop                               19
# David Guetta    hip hop, pop, Dance/Electronic    18
# Beyoncé         pop, R&B                          16
# Kanye West      hip hop                           16
# Taylor Swift    pop                               16
# Chris Brown     hip hop, pop, R&B                 16
# Name: count, dtype: int64

# %%
# Top 10 Artistas rankeados por popularidade
df.groupby('artist').sum().sort_values(by='popularity', ascending=False)['popularity'].head(10)
# Out:
# artist
# Rihanna           1662
# Eminem            1519
# Drake             1424
# Calvin Harris     1356
# Britney Spears    1198
# David Guetta      1185
# Taylor Swift      1125
# Katy Perry        1033
# Beyoncé           1030
# Chris Brown       1012
# Name: popularity, dtype: int64

# %% [markdown]
# Temos praticamente o mesmo registro (linha), exceto pela coluna popularidade. Esse comportamento se repete para as músicas com `value.counts()` = 2

# %%
# Músicas mais populares
df.sort_values(by='popularity', ascending=False)[['artist', 'song', 'duration_min', 'genre', 'year', 'popularity']].head(20)
# Out:
#                  artist                  song  duration_min  \
# 1322  The Neighbourhood       Sweater Weather      4.006667
# 1311          Tom Odell          Another Love      4.072667
# 201              Eminem            Without Me      4.838667
# 1613             WILLOW        Wait a Minute!      3.275333
# 6                Eminem   The Real Slim Shady      4.736667
# 1929      Billie Eilish  lovely (with Khalid)      3.336417
# 1819      Billie Eilish  lovely (with Khalid)      3.336417
# 1512  The Neighbourhood          Daddy Issues      4.336217
# 1709         Ed Sheeran               Perfect      4.390000
# 1999        Post Malone               Circles      3.588000
# 1304         Bruno Mars  Locked out of Heaven      3.891300
# 1227         Bruno Mars  Locked out of Heaven      3.891300
# 209              Eminem      'Till I Collapse      4.963100
# 1514             Avicii            The Nights      2.944300
# 1601              Drake             One Dance      2.899767
# 1712      Billie Eilish                 Bored      3.015550
# 1700         Ed Sheeran          Shape of You      3.895200
# 1910      Lewis Capaldi     Someone You Loved      3.036000
# 1701          Sean Paul                No Lie      3.686267
# 1408        John Legend             All of Me      4.492667
#
#                            genre  year  popularity
# 1322                   rock, pop  2013          89
# 1311                         pop  2013          88
# 201                      hip hop  2002          87
# 1613  pop, R&B, Dance/Electronic  2015          86
# 6                        hip hop  2000          86
# 1929       pop, Dance/Electronic  2018          86
# 1819       pop, Dance/Electronic  2018          86
# 1512                   rock, pop  2015          85
# 1709                         pop  2017          85
# 1999                     hip hop  2019          85
# 1304                         pop  2012          85
# 1227                         pop  2012          85
# 209                      hip hop  2002          85
# 1514       pop, Dance/Electronic  2014          85
# 1601           hip hop, pop, R&B  2016          84
# 1712       pop, Dance/Electronic  2017          84
# 1700                         pop  2017          84
# 1910                         pop  2019          84
# 1701                hip hop, pop  2018          84
# 1408                    pop, R&B  2013          84

# %% [markdown]
# ### Analise com foco na popularidade

# %%
# Influência da duração da música em relação a popularidade
df.sort_values(by='duration_min', ascending=False)[['artist', 'song', 'duration_min', 'genre', 'year', 'popularity']].tail(20)
# Out:
#                 artist                                        song  \
# 717     Fedde Le Grand  Put Your Hands Up For Detroit - Radio Edit
# 1358       Storm Queen          Look Right Through - MK Vocal Edit
# 1933       Post Malone                                        Wow.
# 815         Basshunter                Now You're Gone - Video Edit
# 1773    Zay Hilfigerrr               Juju on That Beat (TZ Anthem)
# 1856          Lil Baby                                  Yes Indeed
# 1526  Lost Frequencies                Are You With Me - Radio Edit
# 1987         iann dior                                   gone girl
# 1809      XXXTENTACION                                   Moonlight
# 1927         Lil Tecca                                      Ransom
# 1936         iann dior                                    emotions
# 1891             Bazzi                                        Mine
# 1966          Blueface                                    Thotiana
# 937             The xx                                       Intro
# 1926          Saweetie                                     My Type
# 1746          Lil Pump                                  Gucci Gang
# 1853      XXXTENTACION                                     changes
# 1752      XXXTENTACION                              Jocelyn Flores
# 1939         Lil Nas X                                      Panini
# 1931         Lil Nas X                               Old Town Road
#
#       duration_min                  genre  year  popularity
# 717       2.508883  pop, Dance/Electronic  2015           0
# 1358      2.506667       Dance/Electronic  2014           0
# 1933      2.492433                hip hop  2019          79
# 815       2.469767                    pop  2008          63
# 1773      2.404067                  set()  2016          57
# 1856      2.371217                hip hop  2018          79
# 1526      2.314033  pop, Dance/Electronic  2014          33
# 1987      2.276133           hip hop, pop  2019          69
# 1809      2.251500                hip hop  2018          82
# 1927      2.187333                hip hop  2019          78
# 1936      2.186883           hip hop, pop  2019          72
# 1891      2.184400  pop, Dance/Electronic  2018          75
# 1966      2.154400                hip hop  2018           1
# 937       2.132000                   rock  2009           2
# 1926      2.107433      hip hop, pop, R&B  2019          71
# 1746      2.067583                hip hop  2017          64
# 1853      2.031433                hip hop  2018          79
# 1752      1.985550                hip hop  2017          83
# 1939      1.914883           hip hop, pop  2019          71
# 1931      1.883333           hip hop, pop  2019          76

# %% [markdown]
# Percentual do tipo de escala musical
#
# A tonalidade maior diz respeito a músicas com um contexto mais alegre, já a escala menor nos remete a músicas mais tristes e instrospectivas

# %%
# Percentual do tipo de escala musical
# A tonalidade maior diz respeito a músicas com um contexto mais alegre, já a escala menor nos remete a músicas mais tristes e instrospectivas
df['mode'].value_counts(normalize=True)
# Out:
# 1    0.5535
# 0    0.4465
# Name: mode, dtype: float64

# %%
# Percentual de músicas com conteúdo explícito
df['explicit'].value_counts(normalize=True)
# Out:
# False    0.7245
# True     0.2755
# Name: explicit, dtype: float64

# %%
df[df['explicit'] == 1].groupby('year').count()['explicit']
# Out:
# year
# 1998     1
# 1999     8
# 2000    12
# 2001    23
# 2002    30
# 2003    23
# 2004    36
# 2005    29
# 2006    26
# 2007    22
# 2008    23
# 2009    23
# 2010    23
# 2011    25
# 2012    19
# 2013    20
# 2014    20
# 2015    29
# 2016    32
# 2017    37
# 2018    51
# 2019    37
# 2020     2
# Name: explicit, dtype: int64
